# %% [markdown]
# <a href="https://colab.research.google.com/github/topatisultan/M.-Topati-Sultan/blob/main/SLO_UAS_LDA_M_Topati_Sultan%20Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/Colab Notebook (1)
# Out:
# /content/drive/My Drive/Colab Notebook (1)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

#baca dataset
dataset = pd.read_csv('data_cancer.csv')

# %%
dataset.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
dataset.shape
# Out:
# (569, 33)

# %%
dataset.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
Y=dataset.diagnosis
drop_cols=['Unnamed: 32','id','diagnosis']
X=dataset.drop(drop_cols,axis=1)
X.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
#Applying Classification
ax=sns.countplot(Y,label='Count',palette='Blues')
B,M=Y.value_counts()
print("Benign Tumours is ", B)
print("Malignant Tumours is ", M)
# Out:
# Benign Tumours is  357
# Malignant Tumours is  212
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# count   569.000000    569.000000  ...      569.000000               569.000000
# mean     14.127292     19.289649  ...        0.290076                 0.083946
# std       3.524049      4.301036  ...        0.061867                 0.018061
# min       6.981000      9.710000  ...        0.156500                 0.055040
# 25%      11.700000     16.170000  ...        0.250400                 0.071460
# 50%      13.370000     18.840000  ...        0.282200                 0.080040
# 75%      15.780000     21.800000  ...        0.317900                 0.092080
# max      28.110000     39.280000  ...        0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
sns.set(style='whitegrid')
data=X
data_std=(data-data.mean())/data.std()
data=pd.concat([Y,data_std.iloc[:,0:10]],axis=1)
data=pd.melt(data,id_vars='diagnosis',var_name='features',value_name='value')
plt.figure(figsize=(10,10))
sns.swarmplot(x='features',y='value',hue='diagnosis',data=data,palette='Blues')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 46.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 44.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 49.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 44.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.set(style='whitegrid')
data=X
data_std=(data-data.mean())/data.std()
data=pd.concat([Y,data_std.iloc[:,10:20]],axis=1)
data=pd.melt(data,id_vars='diagnosis',var_name='features',value_name='value')
plt.figure(figsize=(10,10))
sns.swarmplot(x='features',y='value',hue='diagnosis',data=data,palette='Purples')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 65.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 61.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 66.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 71.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 62.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 64.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 68.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 60.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 68.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
dataset.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig=plt.subplots(figsize=(15,15))
corr=dataset.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(X.corr(),annot=True,linewidth=0.5,fmt='.1f',ax=ax)
plt.show()

# %%
X.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
drop_list = ['perimeter_mean','radius_mean','compactness_mean','concave points_mean',
             'radius_se','perimeter_se','radius_worst','perimeter_worst','compactness_worst',
             'concavity_worst','compactness_se','concave points_se','texture_worst','area_worst']
x1 = X.drop(drop_list ,axis = 1 )        
x1.head()
# Out:
#    texture_mean  area_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         10.38     1001.0  ...          0.4601                  0.11890
# 1         17.77     1326.0  ...          0.2750                  0.08902
# 2         21.25     1203.0  ...          0.3613                  0.08758
# 3         20.38      386.1  ...          0.6638                  0.17300
# 4         14.34     1297.0  ...          0.2364                  0.07678
#
# [5 rows x 16 columns]

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(x1.corr(),annot=True,linewidth=0.5,fmt='.1f',ax=ax)
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x1, Y, test_size=0.2, random_state=21)

#n_estimators=10 (default)
clf_rf = RandomForestClassifier(random_state=42)      
clr_rf = clf_rf.fit(X_train,Y_train)

ac = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ',ac*100)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm/np.sum(cm),annot=True,fmt=".2%",cmap='Blues')
plt.show()
# Out:
# Accuracy is:  97.36842105263158

# %%
#kita buat data (X) dan label nya (Y)
X=dataset.iloc[:, 2:31].values
Y=dataset.iloc[:, 1].values

# %%
from sklearn.preprocessing import LabelEncoder

print("Before encoding: ")
print(Y[100:110])

labelencoder_Y = LabelEncoder()
Y = labelencoder_Y.fit_transform(Y)

print("\nAfter encoding: ")
print(Y[100:110])
# Out:
# Before encoding:
# ['M' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B']
#
# After encoding:
# [1 0 0 0 0 1 0 0 1 0]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state= 0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Applying LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components = 1)
X_train = lda.fit_transform(X_train, Y_train)
X_test = lda.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth = 2, random_state = 0)
clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(Y_test, Y_pred)
print(cm)

print('Accuracy -> ' + str(accuracy_score(Y_test, Y_pred)))
# Out:
# [[65  2]
#  [ 2 45]]
# Accuracy -> 0.9649122807017544

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components = 2, random_state = 0)

# %%
tsne_obj = tsne.fit_transform(X_train)

# %%
tsne_df = pd.DataFrame({'X' : tsne_obj[:,0],
                       'Y' : tsne_obj[:,1],
                        'classification' : Y_train
                       })

# %%
tsne_df.head()
# Out:
#            X          Y  classification
# 0   0.337075 -22.395187               0
# 1  14.376794   9.521049               0
# 2  11.807531  13.471616               0
# 3  10.118971 -14.366254               0
# 4  16.426233   4.602371               0

# %%
tsne_df['classification'].value_counts()
# Out:
# 0    290
# 1    165
# Name: classification, dtype: int64

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'X', y = 'Y', data = tsne_df)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = "X", y = 'Y', hue = 'classification', legend = 'full', data = tsne_df)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('data_cancer.csv')

# %%
X = dataset.iloc[:,2:32] # [all rows, col from index 2 to the last one excluding 'Unnamed: 32']
y = dataset.iloc[:,1] # [all rows, col one only which contains the classes of cancer

# %%
from sklearn.preprocessing import LabelEncoder

print("Before encoding: ")
print(y[100:110])

labelencoder_Y = LabelEncoder()
y = labelencoder_Y.fit_transform(y)

print("\nAfter encoding: ")
print(y[100:110])
# Out:
# Before encoding:
# 100    M
# 101    B
# 102    B
# 103    B
# 104    B
# 105    M
# 106    B
# 107    B
# 108    M
# 109    B
# Name: diagnosis, dtype: object
#
# After encoding:
# [1 0 0 0 0 1 0 0 1 0]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Initialising the ANN

classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 1, epochs = 100)
# Out:
# Epoch 1/100
# 455/455 [==============================] - 1s 971us/step - loss: 0.6248 - accuracy: 0.7347
# Epoch 2/100
# 455/455 [==============================] - 0s 992us/step - loss: 0.1190 - accuracy: 0.9644
# Epoch 3/100
# 455/455 [==============================] - 0s 990us/step - loss: 0.0914 - accuracy: 0.9730
# Epoch 4/100
# 455/455 [==============================] - 0s 998us/step - loss: 0.1098 - accuracy: 0.9749
# Epoch 5/100
# 455/455 [==============================] - 0s 967us/step - loss: 0.0946 - accuracy: 0.9787
# Epoch 6/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0701 - accuracy: 0.9865
# Epoch 7/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0713 - accuracy: 0.9908
# Epoch 8/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1187 - accuracy: 0.9763
# Epoch 9/100
# 455/455 [==============================] - 0s 982us/step - loss: 0.1429 - accuracy: 0.9824
# Epoch 10/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0419 - accuracy: 0.9930
# Epoch 11/100
# 455/455 [==============================] - 0s 996us/step - loss: 0.0556 - accuracy: 0.9919
# Epoch 12/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1030 - accuracy: 0.9865
# Epoch 13/100
# 455/455 [==============================] - 0s 949us/step - loss: 0.0891 - accuracy: 0.9904
# Epoch 14/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0733 - accuracy: 0.9823
# Epoch 15/100
# 455/455 [==============================] - 0s 958us/step - loss: 0.0731 - accuracy: 0.9914
# Epoch 16/100
# 455/455 [==============================] - 0s 940us/step - loss: 0.1234 - accuracy: 0.9788
# Epoch 17/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9840
# Epoch 18/100
# 455/455 [==============================] - 0s 964us/step - loss: 0.0444 - accuracy: 0.9921
# Epoch 19/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9857
# Epoch 20/100
# 455/455 [==============================] - 0s 989us/step - loss: 0.1165 - accuracy: 0.9831
# Epoch 21/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0628 - accuracy: 0.9926
# Epoch 22/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0620 - accuracy: 0.9920
# Epoch 23/100
# 455/455 [==============================] - 0s 992us/step - loss: 0.1032 - accuracy: 0.9855
# Epoch 24/100
# 455/455 [==============================] - 0s 991us/step - loss: 0.0886 - accuracy: 0.9886
# Epoch 25/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0464 - accuracy: 0.9950
# Epoch 26/100
# 455/455 [==============================] - 0s 995us/step - loss: 0.0813 - accuracy: 0.9874
# Epoch 27/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1020 - accuracy: 0.9873
# Epoch 28/100
# 455/455 [==============================] - 0s 974us/step - loss: 0.1445 - accuracy: 0.9828
# Epoch 29/100
# 455/455 [==============================] - 0s 963us/step - loss: 0.1026 - accuracy: 0.9878
# Epoch 30/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0461 - accuracy: 0.9942
# Epoch 31/100
# 455/455 [==============================] - 0s 967us/step - loss: 0.0677 - accuracy: 0.9914
# Epoch 32/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0591 - accuracy: 0.9929
# Epoch 33/100
# 455/455 [==============================] - 0s 961us/step - loss: 0.0298 - accuracy: 0.9967
# Epoch 34/100
# 455/455 [==============================] - 0s 971us/step - loss: 0.1020 - accuracy: 0.9857
# Epoch 35/100
# 455/455 [==============================] - 0s 983us/step - loss: 0.1009 - accuracy: 0.9871
# Epoch 36/100
# 455/455 [==============================] - 0s 967us/step - loss: 0.0545 - accuracy: 0.9928
# Epoch 37/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 0.9968
# Epoch 38/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0240 - accuracy: 0.9972
# Epoch 39/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0540 - accuracy: 0.9933
# Epoch 40/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9882
# Epoch 41/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 0.9885
# Epoch 42/100
# 455/455 [==============================] - 0s 991us/step - loss: 0.0418 - accuracy: 0.9947
# Epoch 43/100
# 455/455 [==============================] - 0s 981us/step - loss: 0.0800 - accuracy: 0.9890
# Epoch 44/100
# 455/455 [==============================] - 1s 1ms/step - loss: 0.0873 - accuracy: 0.9866
# Epoch 45/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1162 - accuracy: 0.9833
# Epoch 46/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9913
# Epoch 47/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0701 - accuracy: 0.9897
# Epoch 48/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0660 - accuracy: 0.9900
# Epoch 49/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1260 - accuracy: 0.9794
# Epoch 50/100
# 455/455 [==============================] - 0s 960us/step - loss: 0.0884 - accuracy: 0.9880
# Epoch 51/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9867
# Epoch 52/100
# 455/455 [==============================] - 0s 967us/step - loss: 0.1625 - accuracy: 0.9746
# Epoch 53/100
# 455/455 [==============================] - 0s 993us/step - loss: 0.0979 - accuracy: 0.9890
# Epoch 54/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.9945
# Epoch 55/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 0.9898
# Epoch 56/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9878
# Epoch 57/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0758 - accuracy: 0.9904
# Epoch 58/100
# 455/455 [==============================] - 1s 1ms/step - loss: 0.0409 - accuracy: 0.9951
# Epoch 59/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 0.9928
# Epoch 60/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 0.9922
# Epoch 61/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9826
# Epoch 62/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0892 - accuracy: 0.9902
# Epoch 63/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0660 - accuracy: 0.9919
# Epoch 64/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0975 - accuracy: 0.9896
# Epoch 65/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9907
# Epoch 66/100
# 455/455 [==============================] - 1s 1ms/step - loss: 0.0759 - accuracy: 0.9901
# Epoch 67/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0473 - accuracy: 0.9950
# Epoch 68/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1632 - accuracy: 0.9841
# Epoch 69/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0577 - accuracy: 0.9929
# Epoch 70/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0862 - accuracy: 0.9882
# Epoch 71/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0712 - accuracy: 0.9933
# Epoch 72/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9841
# Epoch 73/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1163 - accuracy: 0.9866
# Epoch 74/100
# 455/455 [==============================] - 0s 995us/step - loss: 0.0703 - accuracy: 0.9922
# Epoch 75/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 0.9893
# Epoch 76/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1121 - accuracy: 0.9826
# Epoch 77/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 0.9939
# Epoch 78/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0390 - accuracy: 0.9951
# Epoch 79/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.2694 - accuracy: 0.9840
# Epoch 80/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9956
# Epoch 81/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0426 - accuracy: 0.9948
# Epoch 82/100
# 455/455 [==============================] - 0s 999us/step - loss: 0.0623 - accuracy: 0.9910
# Epoch 83/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0734 - accuracy: 0.9898
# Epoch 84/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0521 - accuracy: 0.9934
# Epoch 85/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 0.9921
# Epoch 86/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0707 - accuracy: 0.9887
# Epoch 87/100
# 455/455 [==============================] - 1s 1ms/step - loss: 0.0505 - accuracy: 0.9927
# Epoch 88/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0493 - accuracy: 0.9916
# Epoch 89/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1343 - accuracy: 0.9774
# Epoch 90/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0588 - accuracy: 0.9913
# Epoch 91/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 0.9919
# Epoch 92/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0704 - accuracy: 0.9907
# Epoch 93/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9795
# Epoch 94/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0548 - accuracy: 0.9935
# Epoch 95/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1152 - accuracy: 0.9846
# Epoch 96/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0517 - accuracy: 0.9942
# Epoch 97/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.9854
# Epoch 98/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0931 - accuracy: 0.9844
# Epoch 99/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.0645 - accuracy: 0.9911
# Epoch 100/100
# 455/455 [==============================] - 0s 1ms/step - loss: 0.1576 - accuracy: 0.9837

# %%
from keras.models import load_model

classifier.save('breast_cancer_model.h5')

# %%
y_pred = classifier.predict(X_test)
y_pred = [ 1 if y>=0.5 else 0 for y in y_pred ]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")
# Out:
# [[66  1]
#  [ 3 44]]
# Accuracy: 96.49122807017544%
